# %% [markdown]
# # Experiment

# %%
# Script for generate  experiments
# Imports
from clases.red_rddas_model import RedRddasModel
import ray
import time

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Ray Configurations
ray.init(num_cpus=12, log_to_driver=False)

# Experiment for RDD variation
n_experiments = 10
l_experiments = []
for cont_experiment in range(1,n_experiments+1):
    print("============================")
    print("Experiment:", cont_experiment)
    print("============================")

    # Variable Parameters
    n_rddas_min = 3
    n_rddas_max = 20

    # Fixed Parameters
    n_of_variables_rdda = 5
    n_of_signals_rdda = 2
    n_exit_variables = 2
    n_clauses_function = 2
    type_network = "ALEATORY"
    # this name has to be unique
    unique_path = "21_01_2022"

    # List of Result for the Experiments
    l_res_experiment = []

    v_n_network = 1
    for n_of_rdds in range(n_rddas_min, n_rddas_max + 1):
        print("Number of Network:", v_n_network)
        print("-------------------------------")

        path = "files/" + unique_path + "_" + str(n_of_rdds) + "_" + str(n_of_variables_rdda) + "_" + str(n_of_signals_rdda) \
               + "_" + str(n_exit_variables) + "_" + str(n_clauses_function)

        # generate the RDDAs of the Network of RDDAs
        print("generating the Network of RDDAs ...")
        oRedRddasModel = RedRddasModel(n_of_rdds, n_of_variables_rdda, n_of_signals_rdda, n_exit_variables,
                                       n_clauses_function)

        # Generate the RDDs
        print("generating the rdds ...")
        oRedRddasModel.generate_rddas(type_network=type_network)

        # # Save the Network of RDDAs in a Pickle file
        # RedRddasModel.save_file_pickle(oRedRddasModel, path)
        # path += ".pickle"
        #
        # print("=======================================================")
        # print("The Network of RDDAs is saved in: ", path)

        # Show the Network of RDDAs
        # oRedRddasModel.show()

        # Calculate the Attractors by RDDA and by Signal
        v_begin_0 = time.time()
        result = RedRddasModel.find_attractors_rddas_ray.remote(oRedRddasModel)
        oRedRddasModel = ray.get(result)
        v_end_0 = time.time()
        v_time_0 = v_end_0 - v_begin_0

        # Calculate the Attractors by RDDA and by Signal
        v_begin_1 = time.time()
        result = RedRddasModel.calculation_compatible_pairs.remote(oRedRddasModel)
        oRedRddasModel = ray.get(result)
        v_end_1 = time.time()
        v_time_1 = v_end_1 - v_begin_1

        # # Calculate the Attractors by RDDA and by Signal with iterative Method
        # v_begin_1 = time.time()
        # # result = RedRddasModel.assembly_attractor_fields_iterative.remote(oRedRddasModel)
        # # oRedRddasModel = ray.get(result)
        # v_end_1 = time.time()
        # v_time_1 = v_end_1 - v_begin_1

        # Calculate the Attractors by RDDA and by Signal with optimized Method
        v_begin_2 = time.time()
        result = RedRddasModel.assembly_attractor_fields_optimized.remote(oRedRddasModel)
        oRedRddasModel = ray.get(result)
        v_end_2 = time.time()
        v_time_2 = v_end_2 - v_begin_2

        # Save the results for the experiment , numeric and time indicators
        res_dict = {
                    "n_network": v_n_network,
                    "n_rdds": n_of_rdds,
                    "n_rdda_attractors": len(oRedRddasModel.d_global_rdda_attractor.items()),
                    "t_find_attractors_method": v_time_0,
                    "n_pair_attractors": len(oRedRddasModel.list_attractors_pairs),
                    "t_comp_paris_method": v_time_1,
                    "n_attractor_fields": len(oRedRddasModel.attractor_fields),
                    "t_optimized_method": v_time_2
                    }
        l_res_experiment.append(res_dict)
        v_n_network = v_n_network + 1

    # Read  the Data
    df = pd.DataFrame.from_dict(l_res_experiment)
    l_experiments.append(df)
print("END EXPERIMENT")
# Out:
# ============================
# Experiment: 1
# ============================
# Number of Network: 1
# -------------------------------
# generating the Network of RDDAs ...
# generating the rdds ...
# RDDA :  1
# VARIABLES :  [1, 2, 3, 4, 5]
# RDDA :  2
# VARIABLES :  [6, 7, 8, 9, 10]
# RDDA :  3
# VARIABLES :  [11, 12, 13, 14, 15]
# Generating the True Table
# A ∨ B
# {'15': 'A', '12': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'15': 'A', '12': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'15': 'A', '12': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'15': 'A', '12': 'B'}
# {'A': False, 'B': False}
# Network Input : 1
# Network Output : 3
# Variables : [15, 12]
# Name Variable : 16
# Coupling Function : 15 ∨ 12
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'1': 'A', '4': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'1': 'A', '4': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'1': 'A', '4': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'1': 'A', '4': 'B'}
# {'A': False, 'B': False}
# Network Input : 2
# Network Output : 1
# Variables : [1, 4]
# Name Variable : 17
# Coupling Function : 1 ∨ 4
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'9': 'A', '8': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'9': 'A', '8': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'9': 'A', '8': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'9': 'A', '8': 'B'}
# {'A': False, 'B': False}
# Network Input : 3
# Network Output : 2
# Variables : [9, 8]
# Name Variable : 18
# Coupling Function : 9 ∨ 8
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'4': 'A', '5': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'4': 'A', '5': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'4': 'A', '5': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'4': 'A', '5': 'B'}
# {'A': False, 'B': False}
# Network Input : 3
# Network Output : 1
# Variables : [4, 5]
# Name Variable : 19
# Coupling Function : 4 ∨ 5
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# Number of Network: 2
# -------------------------------
# generating the Network of RDDAs ...
# generating the rdds ...
# RDDA :  1
# VARIABLES :  [1, 2, 3, 4, 5]
# RDDA :  2
# VARIABLES :  [6, 7, 8, 9, 10]
# RDDA :  3
# VARIABLES :  [11, 12, 13, 14, 15]
# RDDA :  4
# VARIABLES :  [16, 17, 18, 19, 20]
# Generating the True Table
# A ∨ B
# {'9': 'A', '6': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'9': 'A', '6': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'9': 'A', '6': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'9': 'A', '6': 'B'}
# {'A': False, 'B': False}
# Network Input : 1
# Network Output : 2
# Variables : [9, 6]
# Name Variable : 21
# Coupling Function : 9 ∨ 6
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'19': 'A', '20': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'19': 'A', '20': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'19': 'A', '20': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'19': 'A', '20': 'B'}
# {'A': False, 'B': False}
# Network Input : 1
# Network Output : 4
# Variables : [19, 20]
# Name Variable : 22
# Coupling Function : 19 ∨ 20
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'11': 'A', '13': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'11': 'A', '13': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'11': 'A', '13': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'11': 'A', '13': 'B'}
# {'A': False, 'B': False}
# Network Input : 2
# Network Output : 3
# Variables : [11, 13]
# Name Variable : 23
# Coupling Function : 11 ∨ 13
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'17': 'A', '16': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'17': 'A', '16': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'17': 'A', '16': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'17': 'A', '16': 'B'}
# {'A': False, 'B': False}
# Network Input : 2
# Network Output : 4
# Variables : [17, 16]
# Name Variable : 24
# Coupling Function : 17 ∨ 16
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'8': 'A', '10': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'8': 'A', '10': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'8': 'A', '10': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'8': 'A', '10': 'B'}
# {'A': False, 'B': False}
# Network Input : 3
# Network Output : 2
# Variables : [8, 10]
# Name Variable : 25
# Coupling Function : 8 ∨ 10
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'1': 'A', '4': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'1': 'A', '4': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'1': 'A', '4': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'1': 'A', '4': 'B'}
# {'A': False, 'B': False}
# Network Input : 4
# Network Output : 1
# Variables : [1, 4]
# Name Variable : 26
# Coupling Function : 1 ∨ 4
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'10': 'A', '8': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'10': 'A', '8': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'10': 'A', '8': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'10': 'A', '8': 'B'}
# {'A': False, 'B': False}
# Network Input : 4
# Network Output : 2
# Variables : [10, 8]
# Name Variable : 27
# Coupling Function : 10 ∨ 8
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# Number of Network: 3
# -------------------------------
# generating the Network of RDDAs ...
# generating the rdds ...
# RDDA :  1
# VARIABLES :  [1, 2, 3, 4, 5]
# RDDA :  2
# VARIABLES :  [6, 7, 8, 9, 10]
# RDDA :  3
# VARIABLES :  [11, 12, 13, 14, 15]
# RDDA :  4
# VARIABLES :  [16, 17, 18, 19, 20]
# RDDA :  5
# VARIABLES :  [21, 22, 23, 24, 25]
# Generating the True Table
# A ∨ B
# {'21': 'A', '22': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'21': 'A', '22': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'21': 'A', '22': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'21': 'A', '22': 'B'}
# {'A': False, 'B': False}
# Network Input : 1
# Network Output : 5
# Variables : [21, 22]
# Name Variable : 26
# Coupling Function : 21 ∨ 22
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'8': 'A', '9': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'8': 'A', '9': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'8': 'A', '9': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'8': 'A', '9': 'B'}
# {'A': False, 'B': False}
# Network Input : 1
# Network Output : 2
# Variables : [8, 9]
# Name Variable : 27
# Coupling Function : 8 ∨ 9
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'12': 'A', '13': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'12': 'A', '13': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'12': 'A', '13': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'12': 'A', '13': 'B'}
# {'A': False, 'B': False}
# Network Input : 2
# Network Output : 3
# Variables : [12, 13]
# Name Variable : 28
# Coupling Function : 12 ∨ 13
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'5': 'A', '3': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'5': 'A', '3': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'5': 'A', '3': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'5': 'A', '3': 'B'}
# {'A': False, 'B': False}
# Network Input : 3
# Network Output : 1
# Variables : [5, 3]
# Name Variable : 29
# Coupling Function : 5 ∨ 3
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'9': 'A', '6': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'9': 'A', '6': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'9': 'A', '6': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'9': 'A', '6': 'B'}
# {'A': False, 'B': False}
# Network Input : 3
# Network Output : 2
# Variables : [9, 6]
# Name Variable : 30
# Coupling Function : 9 ∨ 6
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'24': 'A', '22': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'24': 'A', '22': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'24': 'A', '22': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'24': 'A', '22': 'B'}
# {'A': False, 'B': False}
# Network Input : 4
# Network Output : 5
# Variables : [24, 22]
# Name Variable : 31
# Coupling Function : 24 ∨ 22
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'13': 'A', '14': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'13': 'A', '14': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'13': 'A', '14': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'13': 'A', '14': 'B'}
# {'A': False, 'B': False}
# Network Input : 5
# Network Output : 3
# Variables : [13, 14]
# Name Variable : 32
# Coupling Function : 13 ∨ 14
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'16': 'A', '19': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'16': 'A', '19': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'16': 'A', '19': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'16': 'A', '19': 'B'}
# {'A': False, 'B': False}
# Network Input : 5
# Network Output : 4
# Variables : [16, 19]
# Name Variable : 33
# Coupling Function : 16 ∨ 19
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# Number of Network: 4
# -------------------------------
# generating the Network of RDDAs ...
# generating the rdds ...
# RDDA :  1
# VARIABLES :  [1, 2, 3, 4, 5]
# RDDA :  2
# VARIABLES :  [6, 7, 8, 9, 10]
# RDDA :  3
# VARIABLES :  [11, 12, 13, 14, 15]
# RDDA :  4
# VARIABLES :  [16, 17, 18, 19, 20]
# RDDA :  5
# VARIABLES :  [21, 22, 23, 24, 25]
# RDDA :  6
# VARIABLES :  [26, 27, 28, 29, 30]
# Generating the True Table
# A ∨ B
# {'6': 'A', '7': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'6': 'A', '7': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'6': 'A', '7': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'6': 'A', '7': 'B'}
# {'A': False, 'B': False}
# Network Input : 1
# Network Output : 2
# Variables : [6, 7]
# Name Variable : 31
# Coupling Function : 6 ∨ 7
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'23': 'A', '24': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'23': 'A', '24': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'23': 'A', '24': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'23': 'A', '24': 'B'}
# {'A': False, 'B': False}
# Network Input : 2
# Network Output : 5
# Variables : [23, 24]
# Name Variable : 32
# Coupling Function : 23 ∨ 24
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'22': 'A', '24': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'22': 'A', '24': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'22': 'A', '24': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'22': 'A', '24': 'B'}
# {'A': False, 'B': False}
# Network Input : 3
# Network Output : 5
# Variables : [22, 24]
# Name Variable : 33
# Coupling Function : 22 ∨ 24
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'2': 'A', '4': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'2': 'A', '4': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'2': 'A', '4': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'2': 'A', '4': 'B'}
# {'A': False, 'B': False}
# Network Input : 4
# Network Output : 1
# Variables : [2, 4]
# Name Variable : 34
# Coupling Function : 2 ∨ 4
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'23': 'A', '24': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'23': 'A', '24': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'23': 'A', '24': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'23': 'A', '24': 'B'}
# {'A': False, 'B': False}
# Network Input : 4
# Network Output : 5
# Variables : [23, 24]
# Name Variable : 35
# Coupling Function : 23 ∨ 24
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'20': 'A', '19': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'20': 'A', '19': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'20': 'A', '19': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'20': 'A', '19': 'B'}
# {'A': False, 'B': False}
# Network Input : 5
# Network Output : 4
# Variables : [20, 19]
# Name Variable : 36
# Coupling Function : 20 ∨ 19
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'2': 'A', '5': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'2': 'A', '5': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'2': 'A', '5': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'2': 'A', '5': 'B'}
# {'A': False, 'B': False}
# Network Input : 5
# Network Output : 1
# Variables : [2, 5]
# Name Variable : 37
# Coupling Function : 2 ∨ 5
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'10': 'A', '9': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'10': 'A', '9': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'10': 'A', '9': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'10': 'A', '9': 'B'}
# {'A': False, 'B': False}
# Network Input : 6
# Network Output : 2
# Variables : [10, 9]
# Name Variable : 38
# Coupling Function : 10 ∨ 9
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'5': 'A', '2': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'5': 'A', '2': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'5': 'A', '2': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'5': 'A', '2': 'B'}
# {'A': False, 'B': False}
# Network Input : 6
# Network Output : 1
# Variables : [5, 2]
# Name Variable : 39
# Coupling Function : 5 ∨ 2
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# Number of Network: 5
# -------------------------------
# generating the Network of RDDAs ...
# generating the rdds ...
# RDDA :  1
# VARIABLES :  [1, 2, 3, 4, 5]
# RDDA :  2
# VARIABLES :  [6, 7, 8, 9, 10]
# RDDA :  3
# VARIABLES :  [11, 12, 13, 14, 15]
# RDDA :  4
# VARIABLES :  [16, 17, 18, 19, 20]
# RDDA :  5
# VARIABLES :  [21, 22, 23, 24, 25]
# RDDA :  6
# VARIABLES :  [26, 27, 28, 29, 30]
# RDDA :  7
# VARIABLES :  [31, 32, 33, 34, 35]
# Generating the True Table
# A ∨ B
# {'14': 'A', '15': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'14': 'A', '15': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'14': 'A', '15': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'14': 'A', '15': 'B'}
# {'A': False, 'B': False}
# Network Input : 1
# Network Output : 3
# Variables : [14, 15]
# Name Variable : 36
# Coupling Function : 14 ∨ 15
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'17': 'A', '20': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'17': 'A', '20': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'17': 'A', '20': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'17': 'A', '20': 'B'}
# {'A': False, 'B': False}
# Network Input : 2
# Network Output : 4
# Variables : [17, 20]
# Name Variable : 37
# Coupling Function : 17 ∨ 20
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'24': 'A', '23': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'24': 'A', '23': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'24': 'A', '23': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'24': 'A', '23': 'B'}
# {'A': False, 'B': False}
# Network Input : 2
# Network Output : 5
# Variables : [24, 23]
# Name Variable : 38
# Coupling Function : 24 ∨ 23
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'33': 'A', '35': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'33': 'A', '35': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'33': 'A', '35': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'33': 'A', '35': 'B'}
# {'A': False, 'B': False}
# Network Input : 3
# Network Output : 7
# Variables : [33, 35]
# Name Variable : 39
# Coupling Function : 33 ∨ 35
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'25': 'A', '22': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'25': 'A', '22': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'25': 'A', '22': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'25': 'A', '22': 'B'}
# {'A': False, 'B': False}
# Network Input : 3
# Network Output : 5
# Variables : [25, 22]
# Name Variable : 40
# Coupling Function : 25 ∨ 22
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'34': 'A', '33': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'34': 'A', '33': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'34': 'A', '33': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'34': 'A', '33': 'B'}
# {'A': False, 'B': False}
# Network Input : 4
# Network Output : 7
# Variables : [34, 33]
# Name Variable : 41
# Coupling Function : 34 ∨ 33
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'19': 'A', '17': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'19': 'A', '17': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'19': 'A', '17': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'19': 'A', '17': 'B'}
# {'A': False, 'B': False}
# Network Input : 5
# Network Output : 4
# Variables : [19, 17]
# Name Variable : 42
# Coupling Function : 19 ∨ 17
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'11': 'A', '12': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'11': 'A', '12': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'11': 'A', '12': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'11': 'A', '12': 'B'}
# {'A': False, 'B': False}
# Network Input : 6
# Network Output : 3
# Variables : [11, 12]
# Name Variable : 43
# Coupling Function : 11 ∨ 12
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'1': 'A', '3': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'1': 'A', '3': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'1': 'A', '3': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'1': 'A', '3': 'B'}
# {'A': False, 'B': False}
# Network Input : 6
# Network Output : 1
# Variables : [1, 3]
# Name Variable : 44
# Coupling Function : 1 ∨ 3
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'10': 'A', '6': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'10': 'A', '6': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'10': 'A', '6': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'10': 'A', '6': 'B'}
# {'A': False, 'B': False}
# Network Input : 7
# Network Output : 2
# Variables : [10, 6]
# Name Variable : 45
# Coupling Function : 10 ∨ 6
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'18': 'A', '19': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'18': 'A', '19': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'18': 'A', '19': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'18': 'A', '19': 'B'}
# {'A': False, 'B': False}
# Network Input : 7
# Network Output : 4
# Variables : [18, 19]
# Name Variable : 46
# Coupling Function : 18 ∨ 19
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# Number of Network: 6
# -------------------------------
# generating the Network of RDDAs ...
# generating the rdds ...
# RDDA :  1
# VARIABLES :  [1, 2, 3, 4, 5]
# RDDA :  2
# VARIABLES :  [6, 7, 8, 9, 10]
# RDDA :  3
# VARIABLES :  [11, 12, 13, 14, 15]
# RDDA :  4
# VARIABLES :  [16, 17, 18, 19, 20]
# RDDA :  5
# VARIABLES :  [21, 22, 23, 24, 25]
# RDDA :  6
# VARIABLES :  [26, 27, 28, 29, 30]
# RDDA :  7
# VARIABLES :  [31, 32, 33, 34, 35]
# RDDA :  8
# VARIABLES :  [36, 37, 38, 39, 40]
# Generating the True Table
# A ∨ B
# {'31': 'A', '35': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'31': 'A', '35': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'31': 'A', '35': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'31': 'A', '35': 'B'}
# {'A': False, 'B': False}
# Network Input : 1
# Network Output : 7
# Variables : [31, 35]
# Name Variable : 41
# Coupling Function : 31 ∨ 35
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'15': 'A', '11': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'15': 'A', '11': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'15': 'A', '11': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'15': 'A', '11': 'B'}
# {'A': False, 'B': False}
# Network Input : 2
# Network Output : 3
# Variables : [15, 11]
# Name Variable : 42
# Coupling Function : 15 ∨ 11
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'6': 'A', '8': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'6': 'A', '8': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'6': 'A', '8': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'6': 'A', '8': 'B'}
# {'A': False, 'B': False}
# Network Input : 3
# Network Output : 2
# Variables : [6, 8]
# Name Variable : 43
# Coupling Function : 6 ∨ 8
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'24': 'A', '23': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'24': 'A', '23': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'24': 'A', '23': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'24': 'A', '23': 'B'}
# {'A': False, 'B': False}
# Network Input : 4
# Network Output : 5
# Variables : [24, 23]
# Name Variable : 44
# Coupling Function : 24 ∨ 23
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'7': 'A', '8': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'7': 'A', '8': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'7': 'A', '8': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'7': 'A', '8': 'B'}
# {'A': False, 'B': False}
# Network Input : 4
# Network Output : 2
# Variables : [7, 8]
# Name Variable : 45
# Coupling Function : 7 ∨ 8
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'37': 'A', '38': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'37': 'A', '38': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'37': 'A', '38': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'37': 'A', '38': 'B'}
# {'A': False, 'B': False}
# Network Input : 5
# Network Output : 8
# Variables : [37, 38]
# Name Variable : 46
# Coupling Function : 37 ∨ 38
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'28': 'A', '26': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'28': 'A', '26': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'28': 'A', '26': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'28': 'A', '26': 'B'}
# {'A': False, 'B': False}
# Network Input : 5
# Network Output : 6
# Variables : [28, 26]
# Name Variable : 47
# Coupling Function : 28 ∨ 26
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'32': 'A', '31': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'32': 'A', '31': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'32': 'A', '31': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'32': 'A', '31': 'B'}
# {'A': False, 'B': False}
# Network Input : 6
# Network Output : 7
# Variables : [32, 31]
# Name Variable : 48
# Coupling Function : 32 ∨ 31
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'13': 'A', '11': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'13': 'A', '11': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'13': 'A', '11': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'13': 'A', '11': 'B'}
# {'A': False, 'B': False}
# Network Input : 6
# Network Output : 3
# Variables : [13, 11]
# Name Variable : 49
# Coupling Function : 13 ∨ 11
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'21': 'A', '22': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'21': 'A', '22': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'21': 'A', '22': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'21': 'A', '22': 'B'}
# {'A': False, 'B': False}
# Network Input : 7
# Network Output : 5
# Variables : [21, 22]
# Name Variable : 50
# Coupling Function : 21 ∨ 22
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'17': 'A', '18': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'17': 'A', '18': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'17': 'A', '18': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'17': 'A', '18': 'B'}
# {'A': False, 'B': False}
# Network Input : 7
# Network Output : 4
# Variables : [17, 18]
# Name Variable : 51
# Coupling Function : 17 ∨ 18
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'3': 'A', '5': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'3': 'A', '5': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'3': 'A', '5': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'3': 'A', '5': 'B'}
# {'A': False, 'B': False}
# Network Input : 8
# Network Output : 1
# Variables : [3, 5]
# Name Variable : 52
# Coupling Function : 3 ∨ 5
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'10': 'A', '9': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'10': 'A', '9': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'10': 'A', '9': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'10': 'A', '9': 'B'}
# {'A': False, 'B': False}
# Network Input : 8
# Network Output : 2
# Variables : [10, 9]
# Name Variable : 53
# Coupling Function : 10 ∨ 9
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# Number of Network: 7
# -------------------------------
# generating the Network of RDDAs ...
# generating the rdds ...
# RDDA :  1
# VARIABLES :  [1, 2, 3, 4, 5]
# RDDA :  2
# VARIABLES :  [6, 7, 8, 9, 10]
# RDDA :  3
# VARIABLES :  [11, 12, 13, 14, 15]
# RDDA :  4
# VARIABLES :  [16, 17, 18, 19, 20]
# RDDA :  5
# VARIABLES :  [21, 22, 23, 24, 25]
# RDDA :  6
# VARIABLES :  [26, 27, 28, 29, 30]
# RDDA :  7
# VARIABLES :  [31, 32, 33, 34, 35]
# RDDA :  8
# VARIABLES :  [36, 37, 38, 39, 40]
# RDDA :  9
# VARIABLES :  [41, 42, 43, 44, 45]
# Generating the True Table
# A ∨ B
# {'20': 'A', '16': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'20': 'A', '16': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'20': 'A', '16': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'20': 'A', '16': 'B'}
# {'A': False, 'B': False}
# Network Input : 1
# Network Output : 4
# Variables : [20, 16]
# Name Variable : 46
# Coupling Function : 20 ∨ 16
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'27': 'A', '29': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'27': 'A', '29': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'27': 'A', '29': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'27': 'A', '29': 'B'}
# {'A': False, 'B': False}
# Network Input : 1
# Network Output : 6
# Variables : [27, 29]
# Name Variable : 47
# Coupling Function : 27 ∨ 29
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'27': 'A', '28': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'27': 'A', '28': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'27': 'A', '28': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'27': 'A', '28': 'B'}
# {'A': False, 'B': False}
# Network Input : 2
# Network Output : 6
# Variables : [27, 28]
# Name Variable : 48
# Coupling Function : 27 ∨ 28
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'31': 'A', '32': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'31': 'A', '32': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'31': 'A', '32': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'31': 'A', '32': 'B'}
# {'A': False, 'B': False}
# Network Input : 3
# Network Output : 7
# Variables : [31, 32]
# Name Variable : 49
# Coupling Function : 31 ∨ 32
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'10': 'A', '6': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'10': 'A', '6': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'10': 'A', '6': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'10': 'A', '6': 'B'}
# {'A': False, 'B': False}
# Network Input : 3
# Network Output : 2
# Variables : [10, 6]
# Name Variable : 50
# Coupling Function : 10 ∨ 6
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'24': 'A', '23': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'24': 'A', '23': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'24': 'A', '23': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'24': 'A', '23': 'B'}
# {'A': False, 'B': False}
# Network Input : 4
# Network Output : 5
# Variables : [24, 23]
# Name Variable : 51
# Coupling Function : 24 ∨ 23
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'7': 'A', '10': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'7': 'A', '10': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'7': 'A', '10': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'7': 'A', '10': 'B'}
# {'A': False, 'B': False}
# Network Input : 5
# Network Output : 2
# Variables : [7, 10]
# Name Variable : 52
# Coupling Function : 7 ∨ 10
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'20': 'A', '16': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'20': 'A', '16': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'20': 'A', '16': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'20': 'A', '16': 'B'}
# {'A': False, 'B': False}
# Network Input : 6
# Network Output : 4
# Variables : [20, 16]
# Name Variable : 53
# Coupling Function : 20 ∨ 16
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'43': 'A', '41': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'43': 'A', '41': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'43': 'A', '41': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'43': 'A', '41': 'B'}
# {'A': False, 'B': False}
# Network Input : 6
# Network Output : 9
# Variables : [43, 41]
# Name Variable : 54
# Coupling Function : 43 ∨ 41
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'8': 'A', '9': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'8': 'A', '9': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'8': 'A', '9': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'8': 'A', '9': 'B'}
# {'A': False, 'B': False}
# Network Input : 7
# Network Output : 2
# Variables : [8, 9]
# Name Variable : 55
# Coupling Function : 8 ∨ 9
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'20': 'A', '19': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'20': 'A', '19': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'20': 'A', '19': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'20': 'A', '19': 'B'}
# {'A': False, 'B': False}
# Network Input : 7
# Network Output : 4
# Variables : [20, 19]
# Name Variable : 56
# Coupling Function : 20 ∨ 19
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'10': 'A', '8': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'10': 'A', '8': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'10': 'A', '8': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'10': 'A', '8': 'B'}
# {'A': False, 'B': False}
# Network Input : 8
# Network Output : 2
# Variables : [10, 8]
# Name Variable : 57
# Coupling Function : 10 ∨ 8
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'26': 'A', '27': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'26': 'A', '27': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'26': 'A', '27': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'26': 'A', '27': 'B'}
# {'A': False, 'B': False}
# Network Input : 9
# Network Output : 6
# Variables : [26, 27]
# Name Variable : 58
# Coupling Function : 26 ∨ 27
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'3': 'A', '1': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'3': 'A', '1': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'3': 'A', '1': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'3': 'A', '1': 'B'}
# {'A': False, 'B': False}
# Network Input : 9
# Network Output : 1
# Variables : [3, 1]
# Name Variable : 59
# Coupling Function : 3 ∨ 1
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# Number of Network: 8
# -------------------------------
# generating the Network of RDDAs ...
# generating the rdds ...
# RDDA :  1
# VARIABLES :  [1, 2, 3, 4, 5]
# RDDA :  2
# VARIABLES :  [6, 7, 8, 9, 10]
# RDDA :  3
# VARIABLES :  [11, 12, 13, 14, 15]
# RDDA :  4
# VARIABLES :  [16, 17, 18, 19, 20]
# RDDA :  5
# VARIABLES :  [21, 22, 23, 24, 25]
# RDDA :  6
# VARIABLES :  [26, 27, 28, 29, 30]
# RDDA :  7
# VARIABLES :  [31, 32, 33, 34, 35]
# RDDA :  8
# VARIABLES :  [36, 37, 38, 39, 40]
# RDDA :  9
# VARIABLES :  [41, 42, 43, 44, 45]
# RDDA :  10
# VARIABLES :  [46, 47, 48, 49, 50]
# Generating the True Table
# A ∨ B
# {'27': 'A', '29': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'27': 'A', '29': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'27': 'A', '29': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'27': 'A', '29': 'B'}
# {'A': False, 'B': False}
# Network Input : 1
# Network Output : 6
# Variables : [27, 29]
# Name Variable : 51
# Coupling Function : 27 ∨ 29
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'18': 'A', '19': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'18': 'A', '19': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'18': 'A', '19': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'18': 'A', '19': 'B'}
# {'A': False, 'B': False}
# Network Input : 1
# Network Output : 4
# Variables : [18, 19]
# Name Variable : 52
# Coupling Function : 18 ∨ 19
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'19': 'A', '20': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'19': 'A', '20': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'19': 'A', '20': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'19': 'A', '20': 'B'}
# {'A': False, 'B': False}
# Network Input : 2
# Network Output : 4
# Variables : [19, 20]
# Name Variable : 53
# Coupling Function : 19 ∨ 20
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'21': 'A', '25': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'21': 'A', '25': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'21': 'A', '25': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'21': 'A', '25': 'B'}
# {'A': False, 'B': False}
# Network Input : 3
# Network Output : 5
# Variables : [21, 25]
# Name Variable : 54
# Coupling Function : 21 ∨ 25
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'2': 'A', '5': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'2': 'A', '5': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'2': 'A', '5': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'2': 'A', '5': 'B'}
# {'A': False, 'B': False}
# Network Input : 3
# Network Output : 1
# Variables : [2, 5]
# Name Variable : 55
# Coupling Function : 2 ∨ 5
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'4': 'A', '2': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'4': 'A', '2': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'4': 'A', '2': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'4': 'A', '2': 'B'}
# {'A': False, 'B': False}
# Network Input : 4
# Network Output : 1
# Variables : [4, 2]
# Name Variable : 56
# Coupling Function : 4 ∨ 2
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'28': 'A', '30': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'28': 'A', '30': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'28': 'A', '30': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'28': 'A', '30': 'B'}
# {'A': False, 'B': False}
# Network Input : 4
# Network Output : 6
# Variables : [28, 30]
# Name Variable : 57
# Coupling Function : 28 ∨ 30
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'34': 'A', '32': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'34': 'A', '32': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'34': 'A', '32': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'34': 'A', '32': 'B'}
# {'A': False, 'B': False}
# Network Input : 5
# Network Output : 7
# Variables : [34, 32]
# Name Variable : 58
# Coupling Function : 34 ∨ 32
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'16': 'A', '19': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'16': 'A', '19': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'16': 'A', '19': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'16': 'A', '19': 'B'}
# {'A': False, 'B': False}
# Network Input : 6
# Network Output : 4
# Variables : [16, 19]
# Name Variable : 59
# Coupling Function : 16 ∨ 19
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'34': 'A', '31': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'34': 'A', '31': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'34': 'A', '31': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'34': 'A', '31': 'B'}
# {'A': False, 'B': False}
# Network Input : 6
# Network Output : 7
# Variables : [34, 31]
# Name Variable : 60
# Coupling Function : 34 ∨ 31
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'49': 'A', '46': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'49': 'A', '46': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'49': 'A', '46': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'49': 'A', '46': 'B'}
# {'A': False, 'B': False}
# Network Input : 7
# Network Output : 10
# Variables : [49, 46]
# Name Variable : 61
# Coupling Function : 49 ∨ 46
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'27': 'A', '28': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'27': 'A', '28': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'27': 'A', '28': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'27': 'A', '28': 'B'}
# {'A': False, 'B': False}
# Network Input : 8
# Network Output : 6
# Variables : [27, 28]
# Name Variable : 62
# Coupling Function : 27 ∨ 28
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'37': 'A', '40': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'37': 'A', '40': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'37': 'A', '40': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'37': 'A', '40': 'B'}
# {'A': False, 'B': False}
# Network Input : 9
# Network Output : 8
# Variables : [37, 40]
# Name Variable : 63
# Coupling Function : 37 ∨ 40
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'47': 'A', '49': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'47': 'A', '49': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'47': 'A', '49': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'47': 'A', '49': 'B'}
# {'A': False, 'B': False}
# Network Input : 9
# Network Output : 10
# Variables : [47, 49]
# Name Variable : 64
# Coupling Function : 47 ∨ 49
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'28': 'A', '30': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'28': 'A', '30': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'28': 'A', '30': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'28': 'A', '30': 'B'}
# {'A': False, 'B': False}
# Network Input : 10
# Network Output : 6
# Variables : [28, 30]
# Name Variable : 65
# Coupling Function : 28 ∨ 30
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'43': 'A', '42': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'43': 'A', '42': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'43': 'A', '42': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'43': 'A', '42': 'B'}
# {'A': False, 'B': False}
# Network Input : 10
# Network Output : 9
# Variables : [43, 42]
# Name Variable : 66
# Coupling Function : 43 ∨ 42
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# Number of Network: 9
# -------------------------------
# generating the Network of RDDAs ...
# generating the rdds ...
# RDDA :  1
# VARIABLES :  [1, 2, 3, 4, 5]
# RDDA :  2
# VARIABLES :  [6, 7, 8, 9, 10]
# RDDA :  3
# VARIABLES :  [11, 12, 13, 14, 15]
# RDDA :  4
# VARIABLES :  [16, 17, 18, 19, 20]
# RDDA :  5
# VARIABLES :  [21, 22, 23, 24, 25]
# RDDA :  6
# VARIABLES :  [26, 27, 28, 29, 30]
# RDDA :  7
# VARIABLES :  [31, 32, 33, 34, 35]
# RDDA :  8
# VARIABLES :  [36, 37, 38, 39, 40]
# RDDA :  9
# VARIABLES :  [41, 42, 43, 44, 45]
# RDDA :  10
# VARIABLES :  [46, 47, 48, 49, 50]
# RDDA :  11
# VARIABLES :  [51, 52, 53, 54, 55]
# Generating the True Table
# A ∨ B
# {'40': 'A', '37': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'40': 'A', '37': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'40': 'A', '37': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'40': 'A', '37': 'B'}
# {'A': False, 'B': False}
# Network Input : 1
# Network Output : 8
# Variables : [40, 37]
# Name Variable : 56
# Coupling Function : 40 ∨ 37
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'29': 'A', '28': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'29': 'A', '28': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'29': 'A', '28': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'29': 'A', '28': 'B'}
# {'A': False, 'B': False}
# Network Input : 1
# Network Output : 6
# Variables : [29, 28]
# Name Variable : 57
# Coupling Function : 29 ∨ 28
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'48': 'A', '46': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'48': 'A', '46': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'48': 'A', '46': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'48': 'A', '46': 'B'}
# {'A': False, 'B': False}
# Network Input : 2
# Network Output : 10
# Variables : [48, 46]
# Name Variable : 58
# Coupling Function : 48 ∨ 46
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'4': 'A', '5': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'4': 'A', '5': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'4': 'A', '5': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'4': 'A', '5': 'B'}
# {'A': False, 'B': False}
# Network Input : 2
# Network Output : 1
# Variables : [4, 5]
# Name Variable : 59
# Coupling Function : 4 ∨ 5
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'9': 'A', '7': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'9': 'A', '7': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'9': 'A', '7': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'9': 'A', '7': 'B'}
# {'A': False, 'B': False}
# Network Input : 3
# Network Output : 2
# Variables : [9, 7]
# Name Variable : 60
# Coupling Function : 9 ∨ 7
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'47': 'A', '46': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'47': 'A', '46': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'47': 'A', '46': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'47': 'A', '46': 'B'}
# {'A': False, 'B': False}
# Network Input : 4
# Network Output : 10
# Variables : [47, 46]
# Name Variable : 61
# Coupling Function : 47 ∨ 46
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'20': 'A', '17': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'20': 'A', '17': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'20': 'A', '17': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'20': 'A', '17': 'B'}
# {'A': False, 'B': False}
# Network Input : 5
# Network Output : 4
# Variables : [20, 17]
# Name Variable : 62
# Coupling Function : 20 ∨ 17
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'10': 'A', '9': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'10': 'A', '9': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'10': 'A', '9': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'10': 'A', '9': 'B'}
# {'A': False, 'B': False}
# Network Input : 5
# Network Output : 2
# Variables : [10, 9]
# Name Variable : 63
# Coupling Function : 10 ∨ 9
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'14': 'A', '11': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'14': 'A', '11': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'14': 'A', '11': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'14': 'A', '11': 'B'}
# {'A': False, 'B': False}
# Network Input : 6
# Network Output : 3
# Variables : [14, 11]
# Name Variable : 64
# Coupling Function : 14 ∨ 11
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'52': 'A', '51': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'52': 'A', '51': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'52': 'A', '51': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'52': 'A', '51': 'B'}
# {'A': False, 'B': False}
# Network Input : 6
# Network Output : 11
# Variables : [52, 51]
# Name Variable : 65
# Coupling Function : 52 ∨ 51
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'3': 'A', '1': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'3': 'A', '1': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'3': 'A', '1': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'3': 'A', '1': 'B'}
# {'A': False, 'B': False}
# Network Input : 7
# Network Output : 1
# Variables : [3, 1]
# Name Variable : 66
# Coupling Function : 3 ∨ 1
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'23': 'A', '24': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'23': 'A', '24': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'23': 'A', '24': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'23': 'A', '24': 'B'}
# {'A': False, 'B': False}
# Network Input : 7
# Network Output : 5
# Variables : [23, 24]
# Name Variable : 67
# Coupling Function : 23 ∨ 24
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'6': 'A', '7': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'6': 'A', '7': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'6': 'A', '7': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'6': 'A', '7': 'B'}
# {'A': False, 'B': False}
# Network Input : 8
# Network Output : 2
# Variables : [6, 7]
# Name Variable : 68
# Coupling Function : 6 ∨ 7
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'44': 'A', '42': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'44': 'A', '42': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'44': 'A', '42': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'44': 'A', '42': 'B'}
# {'A': False, 'B': False}
# Network Input : 8
# Network Output : 9
# Variables : [44, 42]
# Name Variable : 69
# Coupling Function : 44 ∨ 42
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'29': 'A', '27': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'29': 'A', '27': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'29': 'A', '27': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'29': 'A', '27': 'B'}
# {'A': False, 'B': False}
# Network Input : 9
# Network Output : 6
# Variables : [29, 27]
# Name Variable : 70
# Coupling Function : 29 ∨ 27
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'4': 'A', '5': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'4': 'A', '5': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'4': 'A', '5': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'4': 'A', '5': 'B'}
# {'A': False, 'B': False}
# Network Input : 10
# Network Output : 1
# Variables : [4, 5]
# Name Variable : 71
# Coupling Function : 4 ∨ 5
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'37': 'A', '36': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'37': 'A', '36': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'37': 'A', '36': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'37': 'A', '36': 'B'}
# {'A': False, 'B': False}
# Network Input : 10
# Network Output : 8
# Variables : [37, 36]
# Name Variable : 72
# Coupling Function : 37 ∨ 36
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'33': 'A', '34': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'33': 'A', '34': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'33': 'A', '34': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'33': 'A', '34': 'B'}
# {'A': False, 'B': False}
# Network Input : 11
# Network Output : 7
# Variables : [33, 34]
# Name Variable : 73
# Coupling Function : 33 ∨ 34
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'40': 'A', '37': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'40': 'A', '37': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'40': 'A', '37': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'40': 'A', '37': 'B'}
# {'A': False, 'B': False}
# Network Input : 11
# Network Output : 8
# Variables : [40, 37]
# Name Variable : 74
# Coupling Function : 40 ∨ 37
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# Number of Network: 10
# -------------------------------
# generating the Network of RDDAs ...
# generating the rdds ...
# RDDA :  1
# VARIABLES :  [1, 2, 3, 4, 5]
# RDDA :  2
# VARIABLES :  [6, 7, 8, 9, 10]
# RDDA :  3
# VARIABLES :  [11, 12, 13, 14, 15]
# RDDA :  4
# VARIABLES :  [16, 17, 18, 19, 20]
# RDDA :  5
# VARIABLES :  [21, 22, 23, 24, 25]
# RDDA :  6
# VARIABLES :  [26, 27, 28, 29, 30]
# RDDA :  7
# VARIABLES :  [31, 32, 33, 34, 35]
# RDDA :  8
# VARIABLES :  [36, 37, 38, 39, 40]
# RDDA :  9
# VARIABLES :  [41, 42, 43, 44, 45]
# RDDA :  10
# VARIABLES :  [46, 47, 48, 49, 50]
# RDDA :  11
# VARIABLES :  [51, 52, 53, 54, 55]
# RDDA :  12
# VARIABLES :  [56, 57, 58, 59, 60]
# Generating the True Table
# A ∨ B
# {'26': 'A', '29': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'26': 'A', '29': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'26': 'A', '29': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'26': 'A', '29': 'B'}
# {'A': False, 'B': False}
# Network Input : 1
# Network Output : 6
# Variables : [26, 29]
# Name Variable : 61
# Coupling Function : 26 ∨ 29
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'14': 'A', '11': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'14': 'A', '11': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'14': 'A', '11': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'14': 'A', '11': 'B'}
# {'A': False, 'B': False}
# Network Input : 1
# Network Output : 3
# Variables : [14, 11]
# Name Variable : 62
# Coupling Function : 14 ∨ 11
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'22': 'A', '24': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'22': 'A', '24': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'22': 'A', '24': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'22': 'A', '24': 'B'}
# {'A': False, 'B': False}
# Network Input : 2
# Network Output : 5
# Variables : [22, 24]
# Name Variable : 63
# Coupling Function : 22 ∨ 24
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'29': 'A', '28': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'29': 'A', '28': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'29': 'A', '28': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'29': 'A', '28': 'B'}
# {'A': False, 'B': False}
# Network Input : 3
# Network Output : 6
# Variables : [29, 28]
# Name Variable : 64
# Coupling Function : 29 ∨ 28
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'39': 'A', '36': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'39': 'A', '36': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'39': 'A', '36': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'39': 'A', '36': 'B'}
# {'A': False, 'B': False}
# Network Input : 3
# Network Output : 8
# Variables : [39, 36]
# Name Variable : 65
# Coupling Function : 39 ∨ 36
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'30': 'A', '29': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'30': 'A', '29': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'30': 'A', '29': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'30': 'A', '29': 'B'}
# {'A': False, 'B': False}
# Network Input : 4
# Network Output : 6
# Variables : [30, 29]
# Name Variable : 66
# Coupling Function : 30 ∨ 29
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'54': 'A', '53': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'54': 'A', '53': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'54': 'A', '53': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# ...
# {'57': 'A', '56': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'57': 'A', '56': 'B'}
# {'A': False, 'B': False}
# Network Input : 8
# Network Output : 12
# Variables : [57, 56]
# Name Variable : 93
# Coupling Function : 57 ∨ 56
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'15': 'A', '11': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'15': 'A', '11': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'15': 'A', '11': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'15': 'A', '11': 'B'}
# {'A': False, 'B': False}
# Network Input : 9
# Network Output : 3
# Variables : [15, 11]
# Name Variable : 94
# Coupling Function : 15 ∨ 11
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'77': 'A', '79': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'77': 'A', '79': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'77': 'A', '79': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'77': 'A', '79': 'B'}
# {'A': False, 'B': False}
# Network Input : 10
# Network Output : 16
# Variables : [77, 79]
# Name Variable : 95
# Coupling Function : 77 ∨ 79
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'63': 'A', '61': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'63': 'A', '61': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'63': 'A', '61': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'63': 'A', '61': 'B'}
# {'A': False, 'B': False}
# Network Input : 11
# Network Output : 13
# Variables : [63, 61]
# Name Variable : 96
# Coupling Function : 63 ∨ 61
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'54': 'A', '51': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'54': 'A', '51': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'54': 'A', '51': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'54': 'A', '51': 'B'}
# {'A': False, 'B': False}
# Network Input : 12
# Network Output : 11
# Variables : [54, 51]
# Name Variable : 97
# Coupling Function : 54 ∨ 51
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'59': 'A', '60': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'59': 'A', '60': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'59': 'A', '60': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'59': 'A', '60': 'B'}
# {'A': False, 'B': False}
# Network Input : 13
# Network Output : 12
# Variables : [59, 60]
# Name Variable : 98
# Coupling Function : 59 ∨ 60
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'2': 'A', '3': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'2': 'A', '3': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'2': 'A', '3': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'2': 'A', '3': 'B'}
# {'A': False, 'B': False}
# Network Input : 13
# Network Output : 1
# Variables : [2, 3]
# Name Variable : 99
# Coupling Function : 2 ∨ 3
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'53': 'A', '52': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'53': 'A', '52': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'53': 'A', '52': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'53': 'A', '52': 'B'}
# {'A': False, 'B': False}
# Network Input : 14
# Network Output : 11
# Variables : [53, 52]
# Name Variable : 100
# Coupling Function : 53 ∨ 52
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'76': 'A', '80': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'76': 'A', '80': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'76': 'A', '80': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'76': 'A', '80': 'B'}
# {'A': False, 'B': False}
# Network Input : 14
# Network Output : 16
# Variables : [76, 80]
# Name Variable : 101
# Coupling Function : 76 ∨ 80
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'11': 'A', '15': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'11': 'A', '15': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'11': 'A', '15': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'11': 'A', '15': 'B'}
# {'A': False, 'B': False}
# Network Input : 15
# Network Output : 3
# Variables : [11, 15]
# Name Variable : 102
# Coupling Function : 11 ∨ 15
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'20': 'A', '19': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'20': 'A', '19': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'20': 'A', '19': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'20': 'A', '19': 'B'}
# {'A': False, 'B': False}
# Network Input : 15
# Network Output : 4
# Variables : [20, 19]
# Name Variable : 103
# Coupling Function : 20 ∨ 19
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'73': 'A', '71': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'73': 'A', '71': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'73': 'A', '71': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'73': 'A', '71': 'B'}
# {'A': False, 'B': False}
# Network Input : 16
# Network Output : 15
# Variables : [73, 71]
# Name Variable : 104
# Coupling Function : 73 ∨ 71
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# Number of Network: 15
# -------------------------------
# generating the Network of RDDAs ...
# generating the rdds ...
# RDDA :  1
# VARIABLES :  [1, 2, 3, 4, 5]
# RDDA :  2
# VARIABLES :  [6, 7, 8, 9, 10]
# RDDA :  3
# VARIABLES :  [11, 12, 13, 14, 15]
# RDDA :  4
# VARIABLES :  [16, 17, 18, 19, 20]
# RDDA :  5
# VARIABLES :  [21, 22, 23, 24, 25]
# RDDA :  6
# VARIABLES :  [26, 27, 28, 29, 30]
# RDDA :  7
# VARIABLES :  [31, 32, 33, 34, 35]
# RDDA :  8
# VARIABLES :  [36, 37, 38, 39, 40]
# RDDA :  9
# VARIABLES :  [41, 42, 43, 44, 45]
# RDDA :  10
# VARIABLES :  [46, 47, 48, 49, 50]
# RDDA :  11
# VARIABLES :  [51, 52, 53, 54, 55]
# RDDA :  12
# VARIABLES :  [56, 57, 58, 59, 60]
# RDDA :  13
# VARIABLES :  [61, 62, 63, 64, 65]
# RDDA :  14
# VARIABLES :  [66, 67, 68, 69, 70]
# RDDA :  15
# VARIABLES :  [71, 72, 73, 74, 75]
# RDDA :  16
# VARIABLES :  [76, 77, 78, 79, 80]
# RDDA :  17
# VARIABLES :  [81, 82, 83, 84, 85]
# Generating the True Table
# A ∨ B
# {'62': 'A', '61': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'62': 'A', '61': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'62': 'A', '61': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'62': 'A', '61': 'B'}
# {'A': False, 'B': False}
# Network Input : 1
# Network Output : 13
# Variables : [62, 61]
# Name Variable : 86
# Coupling Function : 62 ∨ 61
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'7': 'A', '9': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'7': 'A', '9': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'7': 'A', '9': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'7': 'A', '9': 'B'}
# {'A': False, 'B': False}
# Network Input : 1
# Network Output : 2
# Variables : [7, 9]
# Name Variable : 87
# Coupling Function : 7 ∨ 9
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'34': 'A', '35': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'34': 'A', '35': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'34': 'A', '35': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'34': 'A', '35': 'B'}
# {'A': False, 'B': False}
# Network Input : 2
# Network Output : 7
# Variables : [34, 35]
# Name Variable : 88
# Coupling Function : 34 ∨ 35
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'16': 'A', '18': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'16': 'A', '18': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'16': 'A', '18': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'16': 'A', '18': 'B'}
# {'A': False, 'B': False}
# Network Input : 2
# Network Output : 4
# Variables : [16, 18]
# Name Variable : 89
# Coupling Function : 16 ∨ 18
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'1': 'A', '3': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'1': 'A', '3': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'1': 'A', '3': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'1': 'A', '3': 'B'}
# {'A': False, 'B': False}
# Network Input : 3
# Network Output : 1
# Variables : [1, 3]
# Name Variable : 90
# Coupling Function : 1 ∨ 3
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'75': 'A', '74': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'75': 'A', '74': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'75': 'A', '74': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'75': 'A', '74': 'B'}
# {'A': False, 'B': False}
# Network Input : 4
# Network Output : 15
# Variables : [75, 74]
# Name Variable : 91
# Coupling Function : 75 ∨ 74
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'29': 'A', '30': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'29': 'A', '30': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'29': 'A', '30': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'29': 'A', '30': 'B'}
# {'A': False, 'B': False}
# Network Input : 4
# Network Output : 6
# Variables : [29, 30]
# Name Variable : 92
# Coupling Function : 29 ∨ 30
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'30': 'A', '28': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'30': 'A', '28': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'30': 'A', '28': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'30': 'A', '28': 'B'}
# {'A': False, 'B': False}
# Network Input : 5
# Network Output : 6
# Variables : [30, 28]
# Name Variable : 93
# Coupling Function : 30 ∨ 28
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'16': 'A', '17': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'16': 'A', '17': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'16': 'A', '17': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'16': 'A', '17': 'B'}
# {'A': False, 'B': False}
# Network Input : 5
# Network Output : 4
# Variables : [16, 17]
# Name Variable : 94
# Coupling Function : 16 ∨ 17
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'57': 'A', '60': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'57': 'A', '60': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'57': 'A', '60': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'57': 'A', '60': 'B'}
# {'A': False, 'B': False}
# Network Input : 6
# Network Output : 12
# Variables : [57, 60]
# Name Variable : 95
# Coupling Function : 57 ∨ 60
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'36': 'A', '38': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'36': 'A', '38': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'36': 'A', '38': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'36': 'A', '38': 'B'}
# {'A': False, 'B': False}
# Network Input : 7
# Network Output : 8
# Variables : [36, 38]
# Name Variable : 96
# Coupling Function : 36 ∨ 38
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'55': 'A', '51': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'55': 'A', '51': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'55': 'A', '51': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'55': 'A', '51': 'B'}
# {'A': False, 'B': False}
# Network Input : 7
# Network Output : 11
# Variables : [55, 51]
# Name Variable : 97
# Coupling Function : 55 ∨ 51
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'79': 'A', '77': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'79': 'A', '77': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'79': 'A', '77': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'79': 'A', '77': 'B'}
# {'A': False, 'B': False}
# Network Input : 8
# Network Output : 16
# Variables : [79, 77]
# Name Variable : 98
# Coupling Function : 79 ∨ 77
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'7': 'A', '6': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'7': 'A', '6': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'7': 'A', '6': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'7': 'A', '6': 'B'}
# {'A': False, 'B': False}
# Network Input : 8
# Network Output : 2
# Variables : [7, 6]
# Name Variable : 99
# Coupling Function : 7 ∨ 6
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'36': 'A', '40': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'36': 'A', '40': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'36': 'A', '40': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'36': 'A', '40': 'B'}
# {'A': False, 'B': False}
# Network Input : 9
# Network Output : 8
# Variables : [36, 40]
# Name Variable : 100
# Coupling Function : 36 ∨ 40
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'85': 'A', '84': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'85': 'A', '84': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'85': 'A', '84': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'85': 'A', '84': 'B'}
# {'A': False, 'B': False}
# Network Input : 10
# Network Output : 17
# Variables : [85, 84]
# Name Variable : 101
# Coupling Function : 85 ∨ 84
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'69': 'A', '70': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'69': 'A', '70': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'69': 'A', '70': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'69': 'A', '70': 'B'}
# {'A': False, 'B': False}
# Network Input : 11
# Network Output : 14
# Variables : [69, 70]
# Name Variable : 102
# Coupling Function : 69 ∨ 70
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'48': 'A', '50': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'48': 'A', '50': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'48': 'A', '50': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'48': 'A', '50': 'B'}
# {'A': False, 'B': False}
# Network Input : 12
# Network Output : 10
# Variables : [48, 50]
# Name Variable : 103
# Coupling Function : 48 ∨ 50
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'21': 'A', '25': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'21': 'A', '25': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'21': 'A', '25': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'21': 'A', '25': 'B'}
# {'A': False, 'B': False}
# Network Input : 12
# Network Output : 5
# Variables : [21, 25]
# Name Variable : 104
# Coupling Function : 21 ∨ 25
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'34': 'A', '35': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'34': 'A', '35': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'34': 'A', '35': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'34': 'A', '35': 'B'}
# {'A': False, 'B': False}
# Network Input : 13
# Network Output : 7
# Variables : [34, 35]
# Name Variable : 105
# Coupling Function : 34 ∨ 35
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'27': 'A', '29': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'27': 'A', '29': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'27': 'A', '29': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'27': 'A', '29': 'B'}
# {'A': False, 'B': False}
# Network Input : 13
# Network Output : 6
# Variables : [27, 29]
# Name Variable : 106
# Coupling Function : 27 ∨ 29
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'51': 'A', '52': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'51': 'A', '52': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'51': 'A', '52': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'51': 'A', '52': 'B'}
# {'A': False, 'B': False}
# Network Input : 14
# Network Output : 11
# Variables : [51, 52]
# Name Variable : 107
# Coupling Function : 51 ∨ 52
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'58': 'A', '59': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'58': 'A', '59': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'58': 'A', '59': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'58': 'A', '59': 'B'}
# {'A': False, 'B': False}
# Network Input : 15
# Network Output : 12
# Variables : [58, 59]
# Name Variable : 108
# Coupling Function : 58 ∨ 59
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'43': 'A', '44': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'43': 'A', '44': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'43': 'A', '44': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'43': 'A', '44': 'B'}
# {'A': False, 'B': False}
# Network Input : 16
# Network Output : 9
# Variables : [43, 44]
# Name Variable : 109
# Coupling Function : 43 ∨ 44
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# Generating the True Table
# A ∨ B
# {'62': 'A', '61': 'B'}
# {'A': True, 'B': True}
# A ∨ B
# {'62': 'A', '61': 'B'}
# {'A': True, 'B': False}
# A ∨ B
# {'62': 'A', '61': 'B'}
# {'A': False, 'B': True}
# A ∨ B
# {'62': 'A', '61': 'B'}
# {'A': False, 'B': False}
# Network Input : 17
# Network Output : 13
# Variables : [62, 61]
# Name Variable : 110
# Coupling Function : 62 ∨ 61
# Truth Table: {'11': '1', '10': '1', '01': '1', '00': '0'}
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED
# RDDA CREATED

# %% [markdown]
# # Analysing the result

# %% [markdown]
# ### Time vs RDDAs

# %%
# Show the graphs for every experiment
l_labels_y = ["Number of attractors", "Time of find Attractors", "Number of pairs attractors", "Time to compute the attractor pairs", "Number of attractor Fields", "Time of find fields attractors"]
n_experiment = 1
for df in l_experiments:
    fig_, axs = plt.subplots(1,6,figsize=(24,5))
    cont_label = 0
    for (ax, y) in zip(axs, np.asarray(df.keys())[2:]):
        ax.plot(df['n_rdds'], df[y])
        ax.set_xlabel('Number of RDDs by RDDA')
        ax.set_ylabel(l_labels_y[cont_label])
        ax.grid(True)
        cont_label += 1
    fig_.suptitle('Result of the experiment: ' + str(n_experiment), fontsize=16)
    fig_.tight_layout()
    n_experiment +=1

# %%
# Boxplot analysis
l_labels_y = ["Number of attractors", "Time of find Attractors", "Number of pairs attractors", "Time to compute the attractor pairs", "Number of attractor Fields", "Time of find fields attractors"]
n_experiment = 1
for df in l_experiments:
    # Filter the data to show
    
    # Create the Boxplot
    fig1, ax1 = plt.subplots()
    ax1.set_title('Number of Attractors')
    ax1.boxplot(df['n_rdda_attractors'])

# %%
# Analysing the data
for df in l_experiments:
    print(df)

# %%
# Save the result of the experiments in one csv file

# %%
# Save tthe result of the experiment in one pickled file

# %%
# # Show the graphs for every experiment
# l_labels_y = ["Number of attractors", "Time of find Attractors", "Number of pairs attractors", "Time to compute the attractor pairs", "Number of attractor Fields", "Time of find fields attractors"]
# n_experiment = 1
# for df in l_experiments:
#     fig_, axs = plt.subplots(1,6,figsize=(24,5))
#     cont_label = 0
#     for (ax, y) in zip(axs, np.asarray(df.keys())[2:]):
#         ax.plot(df['n_rdds'], df[y])
#         ax.set_xlabel('Number of RDDs by RDDA')
#         ax.set_ylabel(l_labels_y[cont_label])
#         ax.grid(True)
#         cont_label += 1
#     fig_.suptitle('Result of the experiment: ' + str(n_experiment), fontsize=16)
#     fig_.tight_layout()
#     n_experiment +=1

# for v_reg_dict in l_res_experiment:
#     # Show the metrics
#     print("===========================================")
#     print("Result of Network:", v_reg_dict["n_network"])
#     print("===========================================")
#     print("Number of RDDs:", v_reg_dict["n_rdds"])
#     print("Number of Attractors :", v_reg_dict["n_rdda_attractors"])
#     print("Number of Attractor Fields:", v_reg_dict["n_attractor_fields"])
#     print("Duration Compatible Pairs Method :", v_reg_dict["t_comp_paris_method"])
#     # print("Duration Iterative Method :", v_reg_dict["t_iterative_method"])
#     print("Duration Optimized Method:", v_reg_dict["t_optimized_method"])
